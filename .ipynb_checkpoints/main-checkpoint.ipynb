# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a < b:
        return b    
    elif a > b:
        return a

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.219s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    lst1 = sorted(arr)
    return lst1[-1]

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.059s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    lst2 = 0
    for i in arr:
        lst2 += i
    return lst2
    pass

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.059s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    lst3 = 1
    for i in arr:  
        lst3 *= i
    return lst3
    pass

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.062s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    
    if oper == "+":
        lst4 = 0
        for i in arr:
            lst4 += i
    elif oper == "*":
        lst4 = 1
        for i in arr:
            lst4 *= i
    return lst4
        
            
    pass

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.050s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    lst6 = 1
    for i in range(n):
        lst6 *= (i+1)
    return lst6 
    pass

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.059s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    lst7 = []
    for i in arr:
        if i not in lst7:
            lst7.append(i)
    return lst7

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.119s
#
# OK

# %% [markdown]
# ## 8. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(arr):
    lst8 = sorted(arr)
    
    pass

# %%
# This will test your function
#test_stdev(st_dev)

# Our tests need to be improved, so for this exercise, we care about the code itself. You may check if you get
# similar results by checking with:

from statistics import stdev

# %% [markdown]
# ## 9. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    lst9 = 'abcdefghijklmnopqrstuvwxyz'
    for i in lst9:
        if i not in string.lower():
            return False
    return True

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.074s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    letters = "abcdefghijklmnopqrstuvwxyz"
    num = "1234567890"
    special = "#@!$%&()^*[]{}"
    for i in string:
        if len(string) < 8:
            return False
    for i in string:
        if i not in letters:
            return False
    for i in string:    
        if i not in letters.upper():
            return False
    for i in string: 
        if i not in num:
            return False
    for i in string:
        if i not in special:
            return False
    return True

# %%
check_pass('strTidA12fsañls%&(jfdfa5dfa5d!')
# Out:
# False

# %%
def check_pass(string):
    special_characters = "#@!$%&()^*[]{}"
    if len(string) < 8:
        return False
    if not any(c.islower() for c in string):
        return False
    if not any(c.isupper() for c in string):
        return False
    if not any(c.isdigit() for c in string):
        return False
    if not any(c in special_characters for c in string):
        return False
    return True

# %%
check_pass('strTidA12fsañls%&(jfdfa5dfa5d!')
# Out:
# True

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.268s
#
# OK

# %% [markdown]
# ## BONUS

# %% [markdown]
# ## 11. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    import statistics as stats
    mode = stats.mode(arr)
    return mode

# %%
lst = [1,2,3,4,5,6,7,8,9,4,125,14,515,625,61,48,35,5,156,684]   
def mode_counter(lst):
    import statistics as stats
    mode = stats.mode(lst)
    return mode

# %%
print (mode_counter(lst))
# Out:
# 4

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\ima_n\ironhack\semana_1\day_4\lab-functions\mod\testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\ima_n\AppData\Local\Temp\ipykernel_11984\2722100343.py", line 3, in mode_counter
#     mode = max(set(lst), key = speed.count)
# NameError: name 'speed' is not defined
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.297s
#
# FAILED (errors=100)

# %% [markdown]
# ## 12. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass

# %%
# This will test your function 
test_alpha(sort_alpha)
